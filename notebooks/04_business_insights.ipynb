# %% [markdown]
# # 04 — Business Insights
# Profile errors and translate forecasts into inventory, staffing, and promotion decisions.

# %%
import pandas as pd
from pathlib import Path
metrics = pd.read_csv('../reports/model_metrics.csv') if Path('../reports/model_metrics.csv').exists() else pd.DataFrame()
display(metrics)
print('Review forecast bias and RMSPE by store, week, promotion, holiday, and store type.')
print('Use forecasts with safety stock, lead times, and manager override rather than as automatic orders.')
